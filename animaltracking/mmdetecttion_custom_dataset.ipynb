# %% [markdown]
# # Check lib versions

# %%
# %%bash
# # Check nvcc version
# nvcc -V
# echo
# # Check GCC version
# gcc --version
# echo
# # Check the version of torch and cuda packages
# pip list | grep "torch\|cuda"
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_May__3_18:49:52_PDT_2022
# Cuda compilation tools, release 11.7, V11.7.64
# Build cuda_11.7.r11.7/compiler.31294372_0
#
# gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# Copyright (C) 2019 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
#
# cuda-python                   11.6.1
# cupy-cuda115                  9.6.0
# dask-cuda                     22.4.0
# nvidia-dali-cuda110           1.13.0
# pytorch-quantization          2.1.2
# torch                         1.12.0a0+8a1a93a
# torch-tensorrt                1.1.0a0
# torchtext                     0.13.0a0
# torchvision                   0.13.0a0

# %% [markdown]
# # Setup Weights & Biases

# %%
import wandb
import os

os.environ["WANDB_NOTEBOOK_NAME"] = "mmdetecttion_custom_dataset"

wandb.init(project="anastomoticpatchdetection", entity="mjirik")
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find mmdetecttion_custom_dataset.
# wandb: Currently logged in as: mjirik. Use `wandb login --relogin` to force relogin
# wandb version 0.13.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.18
# Run data is saved locally in <code>/auto/plzen1/home/mjirik/projects/ctcodedetector/ctcodedetector/wandb/run-20220901_203147-3eh92usb</code>
# Syncing run <strong><a href="https://wandb.ai/mjirik/anastomoticpatchdetection/runs/3eh92usb" target="_blank">apricot-leaf-3</a></strong> to <a href="https://wandb.ai/mjirik/anastomoticpatchdetection" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/mjirik/anastomoticpatchdetection/runs/3eh92usb?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# Some basic setup

# import some common libraries
import logging
import mmcv.utils

logger = mmcv.utils.get_logger(name="general_logger", log_level=logging.DEBUG)

import matplotlib.pyplot as plt
import numpy as np

# Check Pytorch installation
import torch, torchvision

print(torch.__version__, torch.cuda.is_available())

# Check MMDetection installation
import mmdet

logger.debug(f"mmdet.version={mmdet.__version__}")

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version

logger.debug(get_compiling_cuda_version())
logger.debug(get_compiler_version())
from pprint import pprint, pformat
from mmdet.datasets import build_dataset
from mmdet.apis import train_detector
from mmcv import Config
from mmdet.apis import set_random_seed
from pathlib import Path
import os.path as osp
import os
import mmcv
from mmcv.runner import load_checkpoint

from mmdet.apis import inference_detector, show_result_pyplot
from mmdet.models import build_detector

import skimage
import random
# Out:
# 2022-09-01 20:32:04,709 - general_logger - DEBUG - mmdet.version=2.25.0
# 1.12.0a0+8a1a93a True
# 2022-09-01 20:32:05,060 - general_logger - DEBUG - 11.7
# 2022-09-01 20:32:05,061 - general_logger - DEBUG - GCC 9.4
# NOTE! Installing ujson may make loading annotations faster.

# %%
mmdet.__version__
# Out:
# '2.25.0'

# %% [markdown]
# # Prepare data
#
# Download and copy dataset to scratch dir.

# %%
scratchdir = Path(os.getenv("SCRATCHDIR", "."))

# %%
# !mkdir -p ~/data/orig/cocos2d
# # !cd ~/data/orig/cocos2d
# !wget https://github.com/Tony607/detectron2_instance_segmentation_demo/releases/download/V0.1/data.zip -O data.zip
# !unzip -o data.zip -d ~/data/orig/cocos2d > /dev/null
# !pwd

# %%
# !ls ~/data/orig/cocos2d

# %%
# !echo "$SCRATCHDIR"
# Out:
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz

# %%
# !mkdir -p "$SCRATCHDIR"/data/orig
# !cp -r /storage/plzen4-ntis/projects/korpusy_cv/pilsen_pigs_patches/* "$SCRATCHDIR"/data/orig
# !ls "$SCRATCHDIR"/data/orig
# Out:
# coco_test.json	coco_train.json  images_test  images_train

# %% [markdown]
# # Prepare checkpoint

# %%
import requests
import tqdm

def mywget(url, fname):
    fname = Path(fname)
    fname.parent.mkdir(parents=True, exist_ok=True)
    
    response = requests.get(url, stream=True)
    total_size_in_bytes= int(response.headers.get('content-length', 0))
    block_size = 1024 #1 Kibibyte
    progress_bar = tqdm.tqdm(total=total_size_in_bytes, unit='iB', unit_scale=True)
    with open(fname, 'wb') as file:
        for data in response.iter_content(block_size):
            progress_bar.update(len(data))
            file.write(data)
    progress_bar.close()
    if total_size_in_bytes != 0 and progress_bar.n != total_size_in_bytes:
        print("ERROR, something went wrong")

# %%
mywget(
    "https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco_20210526_095054-1f77628b.pth",
    scratchdir
    / "checkpoints/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco_20210526_095054-1f77628b.pth"
)
# Out:
# 100%|██████████| 167M/167M [00:14<00:00, 11.3MiB/s]

# %%
mmdetection_path = Path(mmdet.__file__).parent.parent

scratchdir = Path(os.getenv("SCRATCHDIR", "."))
logname = Path(os.getenv("LOGNAME", "."))
# from loguru import logger

local_input_data_dir = Path(scratchdir) / "data/orig/"
local_output_data_dir = Path(scratchdir) / "data/processed/"

logger.debug(f"outputdir={local_output_data_dir}")
logger.debug(f"input_data_dir={local_input_data_dir}")
logger.debug(f"input_data_dir exists={local_input_data_dir.exists()}")
logger.debug(f'input_data_dir glob={str(list(local_input_data_dir.glob("**/*")))}')

# Choose to use a config and initialize the detector
config = (
    mmdetection_path
    / "configs/faster_rcnn/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco.py"
)
logger.debug(f"config.exists={config.exists()}")
# Setup a checkpoint file to load
checkpoint_pth = (
    scratchdir
    / "checkpoints/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco_20210526_095054-1f77628b.pth"
)
logger.debug(f"checkpoint_pth.exists={checkpoint_pth.exists()}")

# Set the device to be used for evaluation
device = "cuda:0"

# Load the config
config = mmcv.Config.fromfile(config)
# Set pretrained to be None since we do not need pretrained model here
config.model.pretrained = None

# Initialize the detector
model = build_detector(config.model)

# Load checkpoint
checkpoint = load_checkpoint(model, str(checkpoint_pth), map_location=device)

# Set the classes of models for inference
model.CLASSES = checkpoint["meta"]["CLASSES"]

# We need to set the model's cfg for inference
model.cfg = config

# Convert the model to GPU
model.to(device)
# Convert the model into evaluation mode
model.eval()

# Use the detector to do inference
img = mmdetection_path / "demo/demo.jpg"
result = inference_detector(model, img)
model.show_result(
    img, result, out_file=local_output_data_dir / "demo_output.jpg"
)  # save image with result


# My dataset training
cfg = Config.fromfile(
    mmdetection_path
    / "configs/faster_rcnn/faster_rcnn_r50_caffe_fpn_mstrain_1x_coco.py"
)

# Modify dataset type and path
cfg.dataset_type = "CocoDataset"
cfg.data_root = str(local_input_data_dir)
# cfg.classes = (
#     "bobcat",
#     "opossum",
#     "empty",
#     "coyote",
#     "raccoon",
#     "bird",
#     "dog",
#     "cat",
#     "squirrel",
#     "rabbit",
#     "skunk",
#     "rodent",
#     "badger",
#     "deer",
#     "car",
#     "fox",
# )
# cfg.classes = ('date', 'fig', 'hazelnut',)
cfg.classes = ('patch_on',)

# cfg.data.test.type = "CocoDataset"
# cfg.data.test.data_root = str(local_input_data_dir)
# cfg.data.test.ann_file = "eccv_18_annotation_files_updated/trans_test_annotations.json"
# # cfg.data.test.ann_file = 'eccv_18_annotation_files/trans_test_annotations.json'
# cfg.data.test.img_prefix = "eccv_18_all_images_sm/"
# cfg.data.test.classes = cfg.classes

# cfg.data.train.type = "CocoDataset"
# cfg.data.train.data_root = str(local_input_data_dir)
# cfg.data.train.ann_file = "eccv_18_annotation_files_updated/train_annotations.json"
# # cfg.data.train.ann_file = 'eccv_18_annotation_files/train_annotations.json'
# cfg.data.train.img_prefix = "eccv_18_all_images_sm/"
# cfg.data.train.classes = cfg.classes

# cfg.data.val.type = "CocoDataset"
# cfg.data.val.data_root = str(local_input_data_dir)
# cfg.data.val.ann_file = "eccv_18_annotation_files_updated/trans_val_annotations.json"
# # cfg.data.val.ann_file = 'eccv_18_annotation_files/trans_val_annotations.json'
# cfg.data.val.img_prefix = "eccv_18_all_images_sm/"
# cfg.data.val.classes = cfg.classes


cfg.data.test.type = 'CocoDataset'
cfg.data.test.data_root = str(local_input_data_dir)
cfg.data.test.ann_file = 'coco_test.json'
cfg.data.test.img_prefix = './'
cfg.data.test.classes = cfg.classes

cfg.data.train.type = 'CocoDataset'
cfg.data.train.data_root = str(local_input_data_dir)
cfg.data.train.ann_file = 'coco_train.json'
cfg.data.train.img_prefix = './'
cfg.data.train.classes = cfg.classes

cfg.data.val.type = 'CocoDataset'
cfg.data.val.data_root = str(local_input_data_dir)
cfg.data.val.ann_file = 'coco_test.json'
cfg.data.val.img_prefix = './'
cfg.data.val.classes = cfg.classes


# modify num classes of the model in box head
cfg.model.roi_head.bbox_head.num_classes = 1



# If we need to finetune a model based on a pre-trained detector, we need to
# use load_from to set the path of checkpoints.
cfg.load_from = str(
    scratchdir
    / "checkpoints/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco_20210526_095054-1f77628b.pth"
)

# Set up working dir to save files and logs.
cfg.work_dir = str(local_output_data_dir / "tutorial_exps")

# The original learning rate (LR) is set for 8-GPU training.
# We divide it by 8 since we only use one GPU.
cfg.optimizer.lr = 0.02 / 8
cfg.lr_config.warmup = None
cfg.log_config.interval = 10

# Change the evaluation metric since we use customized dataset.
# cfg.evaluation.metric = 'mAP'
# We can set the evaluation interval to reduce the evaluation times
cfg.evaluation.interval = 12
# We can set the checkpoint saving interval to reduce the storage cost
cfg.checkpoint_config.interval = 12

# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

def is_mlu_available():
    """Returns a bool indicating if MLU is currently available."""
    return hasattr(torch, 'is_mlu_available') and torch.is_mlu_available()


def get_device():
    """Returns an available device, cpu, cuda or mlu."""
    is_device_available = {
        'cuda': torch.cuda.is_available(),
        'mlu': is_mlu_available()
    }
    device_list = [k for k, v in is_device_available.items() if v]
    return device_list[0] if len(device_list) == 1 else 'cpu'

cfg.device = get_device()

# We can also use tensorboard to log the training process
cfg.log_config.hooks = [
    dict(type="TextLoggerHook"), dict(type="TensorboardLoggerHook"),
    # dict(type='MMDetWandbHook',
    #      init_kwargs={'project': 'anastomoticpatchdetection'},
    #      interval=10,
    #      log_checkpoint=True,
    #      log_checkpoint_metadata=True,
    #      num_eval_images=3,
    #      bbox_score_thr=0.3)

]


# We can initialize the logger for training and have a look
# at the final config used for training
# print(f'Config:\n{cfg.pretty_text}') # does not work for paths beginning '/' because of bug in lib2to3

logger.debug(f"cfg=\n{pformat(cfg)}")

# Build dataset
datasets = [build_dataset(cfg.data.train)]

logger.debug(f"classes={datasets[0].CLASSES}")

# Build the detector
model = build_detector(cfg.model)
# Add an attribute for visualization convenience
model.CLASSES = datasets[0].CLASSES


# Create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2022-09-01 21:27:10,755 - general_logger - DEBUG - outputdir=/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed
# 2022-09-01 21:27:10,756 - general_logger - DEBUG - input_data_dir=/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig
# 2022-09-01 21:27:10,757 - general_logger - DEBUG - input_data_dir exists=True
# 2022-09-01 21:27:10,759 - general_logger - DEBUG - input_data_dir glob=[PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/coco_test.json'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/coco_train.json'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00001.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00002.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00003.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00004.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00005.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00006.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00007.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00008.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00009.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00010.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00011.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00012.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00013.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00014.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00015.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00016.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00017.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00018.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00019.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00020.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00001.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00002.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00003.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00004.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00005.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00006.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00007.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00008.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00009.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00010.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00011.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00012.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00013.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00014.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_train/00015.jpg'), PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_tra ...
# 2022-09-01 21:27:10,761 - general_logger - DEBUG - config.exists=True
# 2022-09-01 21:27:10,762 - general_logger - DEBUG - checkpoint_pth.exists=True
# load checkpoint from local path: /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/checkpoints/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco_20210526_095054-1f77628b.pth
# /workspace/mmdetection/mmdet/datasets/utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(
# 2022-09-01 21:27:11,790 - general_logger - DEBUG - cfg=
# Config (path: /workspace/mmdetection/configs/faster_rcnn/faster_rcnn_r50_caffe_fpn_mstrain_1x_coco.py): {'model': {'type': 'FasterRCNN', 'backbone': {'type': 'ResNet', 'depth': 50, 'num_stages': 4, 'out_indices': (0, 1, 2, 3), 'frozen_stages': 1, 'norm_cfg': {'type': 'BN', 'requires_grad': False}, 'norm_eval': True, 'style': 'caffe', 'init_cfg': {'type': 'Pretrained', 'checkpoint': 'open-mmlab://detectron2/resnet50_caffe'}}, 'neck': {'type': 'FPN', 'in_channels': [256, 512, 1024, 2048], 'out_channels': 256, 'num_outs': 5}, 'rpn_head': {'type': 'RPNHead', 'in_channels': 256, 'feat_channels': 256, 'anchor_generator': {'type': 'AnchorGenerator', 'scales': [8], 'ratios': [0.5, 1.0, 2.0], 'strides': [4, 8, 16, 32, 64]}, 'bbox_coder': {'type': 'DeltaXYWHBBoxCoder', 'target_means': [0.0, 0.0, 0.0, 0.0], 'target_stds': [1.0, 1.0, 1.0, 1.0]}, 'loss_cls': {'type': 'CrossEntropyLoss', 'use_sigmoid': True, 'loss_weight': 1.0}, 'loss_bbox': {'type': 'L1Loss', 'loss_weight': 1.0}}, 'roi_head': {'type': 'StandardRoIHead', 'bbox_roi_extractor': {'type': 'SingleRoIExtractor', 'roi_layer': {'type': 'RoIAlign', 'output_size': 7, 'sampling_ratio': 0}, 'out_channels': 256, 'featmap_strides': [4, 8, 16, 32]}, 'bbox_head': {'type': 'Shared2FCBBoxHead', 'in_channels': 256, 'fc_out_channels': 1024, 'roi_feat_size': 7, 'num_classes': 1, 'bbox_coder': {'type': 'DeltaXYWHBBoxCoder', 'target_means': [0.0, 0.0, 0.0, 0.0], 'target_stds': [0.1, 0.1, 0.2, 0.2]}, 'reg_class_agnostic': False, 'loss_cls': {'type': 'CrossEntropyLoss', 'use_sigmoid': False, 'loss_weight': 1.0}, 'loss_bbox': {'type': 'L1Loss', 'loss_weight': 1.0}}}, 'train_cfg': {'rpn': {'assigner': {'type': 'MaxIoUAssigner', 'pos_iou_thr': 0.7, 'neg_iou_thr': 0.3, 'min_pos_iou': 0.3, 'match_low_quality': True, 'ignore_iof_thr': -1}, 'sampler': {'type': 'RandomSampler', 'num': 256, 'pos_fraction': 0.5, 'neg_pos_ub': -1, 'add_gt_as_proposals': False}, 'allowed_border': -1, 'pos_weight': -1, 'debug': False}, 'rpn_proposal': {'nms_pre': 2000, 'max_per_img': 1000, 'nms': {'type': 'nms', 'iou_threshold': 0.7}, 'min_bbox_size': 0}, 'rcnn': {'assigner': {'type': 'MaxIoUAssigner', 'pos_iou_thr': 0.5, 'neg_iou_thr': 0.5, 'min_pos_iou': 0.5, 'match_low_quality': False, 'ignore_iof_thr': -1}, 'sampler': {'type': 'RandomSampler', 'num': 512, 'pos_fraction': 0.25, 'neg_pos_ub': -1, 'add_gt_as_proposals': True}, 'pos_weight': -1, 'debug': False}}, 'test_cfg': {'rpn': {'nms_pre': 1000, 'max_per_img': 1000, 'nms': {'type': 'nms', 'iou_threshold': 0.7}, 'min_bbox_size': 0}, 'rcnn': {'score_thr': 0.05, 'nms': {'type': 'nms', 'iou_threshold': 0.5}, 'max_per_img': 100}}}, 'dataset_type': 'CocoDataset', 'data_root': '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig', 'img_norm_cfg': {'mean': [103.53, 116.28, 123.675], 'std': [1.0, 1.0, 1.0], 'to_rgb': False}, 'train_pipeline': [{'type': 'LoadImageFromFile'}, {'type': 'LoadAnnotations', 'with_bbox': True}, {'type': 'Resize', 'img_scale': [(1333, 640), (1333, 672), (1333, 704), (1333, 736), (1333, 768), (1333, 800)], 'multiscale_mode': 'value', 'keep_ratio': True}, {'type': 'RandomFlip', 'flip_ratio': 0.5}, {'type': 'Normalize', 'mean': [103.53, 116.28, 123.675], 'std': [1.0, 1.0, 1.0], 'to_rgb': False}, {'type': 'Pad', 'size_divisor': 32}, {'type': 'DefaultFormatBundle'}, {'type': 'Collect', 'keys': ['img', 'gt_bboxes', 'gt_labels']}], 'test_pipeline': [{'type': 'LoadImageFromFile'}, {'type': 'MultiScaleFlipAug', 'img_scale': (1333, 800), 'flip': False, 'transforms': [{'type': 'Resize', 'keep_ratio': True}, {'type': 'RandomFlip'}, {'type': 'Normalize', 'mean': [103.53, 116.28, 123.675], 'std': [1.0, 1.0, 1.0], 'to_rgb': False}, {'type': 'Pad', 'size_divisor': 32}, {'type': 'ImageToTensor', 'keys': ['img']}, {'type': 'Collect', 'keys': ['img']}]}], 'data': {'samples_per_gpu': 2, 'workers_per_gpu': 2, 'train': {'type': 'CocoDataset', 'ann_file': 'coco_train.json', 'img_prefix': './', 'pipeline': [{'type': 'LoadImageFromFile'}, {'type': 'LoadAnnotations', 'wi ...
# 2022-09-01 21:27:11,793 - general_logger - DEBUG - classes=('patch_on',)
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 2022-09-01 21:27:12,231 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2022-09-01 21:27:12,235 - mmdet - INFO - load checkpoint from local path: /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/checkpoints/faster_rcnn_r50_caffe_fpn_mstrain_3x_coco_20210526_095054-1f77628b.pth
# 2022-09-01 21:27:12,345 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([2, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([2]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([4, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([4]).
# 2022-09-01 21:27:12,347 - mmdet - INFO - Start running, host: mjirik@konos5.fav.zcu.cz, work_dir: /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps
# 2022-09-01 21:27:12,348 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-09-01 21:27:12,350 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2022-09-01 21:27:12,350 - mmdet - INFO - Checkpoints will be saved to /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps by HardDiskBackend.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 2022-09-01 21:27:19,156 - mmdet - INFO - Epoch [1][10/31]	lr: 2.500e-03, eta: 0:04:01, time: 0.667, data_time: 0.241, memory: 4099, loss_rpn_cls: 0.0704, loss_rpn_bbox: 0.0095, loss_cls: 0.1264, acc: 97.4902, loss_bbox: 0.0389, loss: 0.2451
# 2022-09-01 21:27:22,096 - mmdet - INFO - Epoch [1][20/31]	lr: 2.500e-03, eta: 0:02:49, time: 0.294, data_time: 0.021, memory: 4099, loss_rpn_cls: 0.0343, loss_rpn_bbox: 0.0055, loss_cls: 0.0851, acc: 97.0117, loss_bbox: 0.1155, loss: 0.2404
# 2022-09-01 21:27:25,074 - mmdet - INFO - Epoch [1][30/31]	lr: 2.500e-03, eta: 0:02:23, time: 0.297, data_time: 0.021, memory: 4099, loss_rpn_cls: 0.0324, loss_rpn_bbox: 0.0063, loss_cls: 0.0833, acc: 97.1484, loss_bbox: 0.1131, loss: 0.2351
# 2022-09-01 21:27:30,795 - mmdet - INFO - Epoch [2][10/31]	lr: 2.500e-03, eta: 0:02:24, time: 0.531, data_time: 0.238, memory: 4099, loss_rpn_cls: 0.0114, loss_rpn_bbox: 0.0058, loss_cls: 0.0793, acc: 96.7969, loss_bbox: 0.1345, loss: 0.2310
# 2022-09-01 21:27:33,771 - mmdet - INFO - Epoch [2][20/31]	lr: 2.500e-03, eta: 0:02:11, time: 0.302, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0056, loss_rpn_bbox: 0.0045, loss_cls: 0.0711, acc: 97.3535, loss_bbox: 0.1331, loss: 0.2143
# 2022-09-01 21:27:36,840 - mmdet - INFO - Epoch [2][30/31]	lr: 2.500e-03, eta: 0:02:01, time: 0.303, data_time: 0.019, memory: 4099, loss_rpn_cls: 0.0023, loss_rpn_bbox: 0.0032, loss_cls: 0.0692, acc: 97.5879, loss_bbox: 0.1276, loss: 0.2022
# 2022-09-01 21:27:42,308 - mmdet - INFO - Epoch [3][10/31]	lr: 2.500e-03, eta: 0:02:00, time: 0.511, data_time: 0.237, memory: 4099, loss_rpn_cls: 0.0036, loss_rpn_bbox: 0.0040, loss_cls: 0.0607, acc: 97.5977, loss_bbox: 0.1201, loss: 0.1884
# 2022-09-01 21:27:45,317 - mmdet - INFO - Epoch [3][20/31]	lr: 2.500e-03, eta: 0:01:53, time: 0.299, data_time: 0.021, memory: 4099, loss_rpn_cls: 0.0069, loss_rpn_bbox: 0.0039, loss_cls: 0.0665, acc: 97.6270, loss_bbox: 0.1128, loss: 0.1901
# 2022-09-01 21:27:48,402 - mmdet - INFO - Epoch [3][30/31]	lr: 2.500e-03, eta: 0:01:46, time: 0.308, data_time: 0.022, memory: 4099, loss_rpn_cls: 0.0030, loss_rpn_bbox: 0.0038, loss_cls: 0.0718, acc: 97.5391, loss_bbox: 0.1159, loss: 0.1947
# 2022-09-01 21:27:53,988 - mmdet - INFO - Epoch [4][10/31]	lr: 2.500e-03, eta: 0:01:45, time: 0.518, data_time: 0.240, memory: 4099, loss_rpn_cls: 0.0018, loss_rpn_bbox: 0.0050, loss_cls: 0.0494, acc: 97.7930, loss_bbox: 0.1163, loss: 0.1725
# 2022-09-01 21:27:56,978 - mmdet - INFO - Epoch [4][20/31]	lr: 2.500e-03, eta: 0:01:39, time: 0.299, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0031, loss_cls: 0.0463, acc: 97.8223, loss_bbox: 0.1056, loss: 0.1556
# 2022-09-01 21:27:59,994 - mmdet - INFO - Epoch [4][30/31]	lr: 2.500e-03, eta: 0:01:33, time: 0.304, data_time: 0.022, memory: 4099, loss_rpn_cls: 0.0018, loss_rpn_bbox: 0.0031, loss_cls: 0.0504, acc: 98.0273, loss_bbox: 0.0914, loss: 0.1467
# 2022-09-01 21:28:05,633 - mmdet - INFO - Epoch [5][10/31]	lr: 2.500e-03, eta: 0:01:31, time: 0.523, data_time: 0.237, memory: 4099, loss_rpn_cls: 0.0018, loss_rpn_bbox: 0.0039, loss_cls: 0.0442, acc: 98.1055, loss_bbox: 0.1042, loss: 0.1542
# 2022-09-01 21:28:08,586 - mmdet - INFO - Epoch [5][20/31]	lr: 2.500e-03, eta: 0:01:26, time: 0.298, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0032, loss_cls: 0.0406, acc: 98.3008, loss_bbox: 0.0973, loss: 0.1418
# 2022-09-01 21:28:11,702 - mmdet - INFO - Epoch [5][30/31]	lr: 2.500e-03, eta: 0:01:21, time: 0.307, data_time: 0.020, memory: 4099, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0042, loss_cls: 0.0440, acc: 98.1641, loss_bbox: 0.0964, loss: 0.1452
# 2022-09-01 21:28:17,311 - mmdet - INFO - Epoch [6][10/31]	lr: 2.500e-03, eta: 0:01:18, time: 0.521, data_time: 0.237, memory: 4099, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0026, loss_cls: 0.0426, acc: 98.0957, loss_bbox: 0.0992, loss: 0.1448
# 2022-09-01 21:28:20,262 - mmdet - INFO - Epoch [6][20/31]	lr: 2.500e-03, eta: 0:01:14, time: 0.298, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0033, loss_cls: 0.0394, acc: 98.3203, loss_bbox: 0.0935, loss: 0.1364
# 2022-09-01 21:28:23,368 - mmdet - INFO - Epoch [6][30/31]	lr: 2.500e-03, eta: 0:01:09, time: 0.307, data_time: 0.020, memory: 4099, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0035, loss_cls: 0.0465, acc: 98.0469, loss_bbox: 0.0791, loss: 0.1294
# 2022-09-01 21:28:29,081 - mmdet - INFO - Epoch [7][10/31]	lr: 2.500e-03, eta: 0:01:06, time: 0.531, data_time: 0.240, memory: 4099, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0029, loss_cls: 0.0386, acc: 98.4375, loss_bbox: 0.0825, loss: 0.1253
# 2022-09-01 21:28:32,188 - mmdet - INFO - Epoch [7][20/31]	lr: 2.500e-03, eta: 0:01:02, time: 0.310, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0006, loss_rpn_bbox: 0.0037, loss_cls: 0.0339, acc: 98.5254, loss_bbox: 0.0707, loss: 0.1089
# 2022-09-01 21:28:35,307 - mmdet - INFO - Epoch [7][30/31]	lr: 2.500e-03, eta: 0:00:58, time: 0.311, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0034, loss_cls: 0.0373, acc: 98.3789, loss_bbox: 0.0740, loss: 0.1150
# 2022-09-01 21:28:40,888 - mmdet - INFO - Epoch [8][10/31]	lr: 2.500e-03, eta: 0:00:54, time: 0.519, data_time: 0.238, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0031, loss_cls: 0.0379, acc: 98.4375, loss_bbox: 0.0796, loss: 0.1208
# 2022-09-01 21:28:43,995 - mmdet - INFO - Epoch [8][20/31]	lr: 2.500e-03, eta: 0:00:50, time: 0.311, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0005, loss_rpn_bbox: 0.0028, loss_cls: 0.0390, acc: 98.3203, loss_bbox: 0.0837, loss: 0.1259
# 2022-09-01 21:28:47,102 - mmdet - INFO - Epoch [8][30/31]	lr: 2.500e-03, eta: 0:00:46, time: 0.309, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0030, loss_cls: 0.0387, acc: 98.6133, loss_bbox: 0.0884, loss: 0.1306
# 2022-09-01 21:28:52,765 - mmdet - INFO - Epoch [9][10/31]	lr: 2.500e-04, eta: 0:00:42, time: 0.524, data_time: 0.234, memory: 4099, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0031, loss_cls: 0.0374, acc: 98.3398, loss_bbox: 0.0802, loss: 0.1210
# 2022-09-01 21:28:55,864 - mmdet - INFO - Epoch [9][20/31]	lr: 2.500e-04, eta: 0:00:38, time: 0.310, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0029, loss_cls: 0.0323, acc: 98.7695, loss_bbox: 0.0684, loss: 0.1038
# 2022-09-01 21:28:59,025 - mmdet - INFO - Epoch [9][30/31]	lr: 2.500e-04, eta: 0:00:34, time: 0.317, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0022, loss_cls: 0.0341, acc: 98.4961, loss_bbox: 0.0725, loss: 0.1089
# 2022-09-01 21:29:04,678 - mmdet - INFO - Epoch [10][10/31]	lr: 2.500e-04, eta: 0:00:31, time: 0.525, data_time: 0.238, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0025, loss_cls: 0.0313, acc: 98.7109, loss_bbox: 0.0580, loss: 0.0920
# 2022-09-01 21:29:07,653 - mmdet - INFO - Epoch [10][20/31]	lr: 2.500e-04, eta: 0:00:27, time: 0.299, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0002, loss_rpn_bbox: 0.0023, loss_cls: 0.0361, acc: 98.4082, loss_bbox: 0.0690, loss: 0.1075
# 2022-09-01 21:29:10,751 - mmdet - INFO - Epoch [10][30/31]	lr: 2.500e-04, eta: 0:00:23, time: 0.309, data_time: 0.021, memory: 4099, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0022, loss_cls: 0.0295, acc: 98.9062, loss_bbox: 0.0581, loss: 0.0901
# 2022-09-01 21:29:16,456 - mmdet - INFO - Epoch [11][10/31]	lr: 2.500e-04, eta: 0:00:19, time: 0.530, data_time: 0.238, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0036, loss_cls: 0.0339, acc: 98.6230, loss_bbox: 0.0668, loss: 0.1044
# 2022-09-01 21:29:19,445 - mmdet - INFO - Epoch [11][20/31]	lr: 2.500e-04, eta: 0:00:15, time: 0.299, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0021, loss_cls: 0.0292, acc: 98.6523, loss_bbox: 0.0615, loss: 0.0929
# 2022-09-01 21:29:22,613 - mmdet - INFO - Epoch [11][30/31]	lr: 2.500e-04, eta: 0:00:11, time: 0.316, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0003, loss_rpn_bbox: 0.0021, loss_cls: 0.0317, acc: 98.6719, loss_bbox: 0.0625, loss: 0.0966
# 2022-09-01 21:29:28,291 - mmdet - INFO - Epoch [12][10/31]	lr: 2.500e-05, eta: 0:00:07, time: 0.527, data_time: 0.237, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0019, loss_cls: 0.0259, acc: 98.9453, loss_bbox: 0.0510, loss: 0.0789
# 2022-09-01 21:29:31,296 - mmdet - INFO - Epoch [12][20/31]	lr: 2.500e-05, eta: 0:00:04, time: 0.301, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0004, loss_rpn_bbox: 0.0023, loss_cls: 0.0350, acc: 98.4863, loss_bbox: 0.0725, loss: 0.1102
# 2022-09-01 21:29:34,396 - mmdet - INFO - Epoch [12][30/31]	lr: 2.500e-05, eta: 0:00:00, time: 0.310, data_time: 0.023, memory: 4099, loss_rpn_cls: 0.0001, loss_rpn_bbox: 0.0022, loss_cls: 0.0323, acc: 98.6035, loss_bbox: 0.0594, loss: 0.0940
# 2022-09-01 21:29:34,651 - mmdet - INFO - Saving checkpoint at 12 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 20/20, 11.4 task/s, elapsed: 2s, ETA:     0s
# 2022-09-01 21:29:37,271 - mmdet - INFO - Evaluating bbox...
# 2022-09-01 21:29:37,293 - mmdet - INFO -
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.37237
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.91794
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.20438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.00000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.37266
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.00000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.42500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.42500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.42500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.00000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.42500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.00000
#
# 2022-09-01 21:29:37,296 - mmdet - INFO - Epoch(val) [12][20]	bbox_mAP: 0.3720, bbox_mAP_50: 0.9180, bbox_mAP_75: 0.2040, bbox_mAP_s: -1.0000, bbox_mAP_m: 0.3730, bbox_mAP_l: -1.0000, bbox_mAP_copypaste: 0.372 0.918 0.204 -1.000 0.373 -1.000
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).

# %%
# !ls $local_input_data_dir/images_test
# Out:
# 00001.jpg  00004.jpg  00007.jpg  00010.jpg  00013.jpg  00016.jpg  00019.jpg
# 00002.jpg  00005.jpg  00008.jpg  00011.jpg  00014.jpg  00017.jpg  00020.jpg
# 00003.jpg  00006.jpg  00009.jpg  00012.jpg  00015.jpg  00018.jpg

# %%
datasets[0]
# Out:
# CocoDataset Train dataset with number of images 60, and instance counts:
# +--------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
# | category     | count | category | count | category | count | category | count | category | count |
# +--------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
# |              |       |          |       |          |       |          |       |          |       |
# | 0 [patch_on] | 60    |          |       |          |       |          |       |          |       |
# +--------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+

# %%
path_test_images = local_input_data_dir /"images_test"
# path_test_images = local_input_data_dir / cfg.data.test.img_prefix
#  = 'images/'
filelist = list((path_test_images).glob("*.jpg"))
filelist.extend(list((path_test_images).glob("*.png")))

for img_fn in filelist:

    # img_fn = local_input_data_dir / '/images/10.jpg'
    img = mmcv.imread(img_fn)

    model.cfg = cfg
    result = inference_detector(model, img)
    # show_result_pyplot(model, img, result)
    model.show_result(
        img, result, out_file=local_output_data_dir / f"pred_{img_fn.stem}.jpg"
    )  # save image with result

# # print all files in input dir recursively to check everything
logger.debug(str(list(map(str, list(Path(local_output_data_dir).glob("**/*"))))))
# Out:
# 2022-09-01 21:32:06,924 - general_logger - DEBUG - ['/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/demo_output.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00001.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00002.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00003.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00004.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00005.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00006.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00007.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00008.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00009.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00010.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00011.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00012.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00013.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00014.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00015.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00016.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00017.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00018.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00019.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00020.jpg', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/tf_logs', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/None.log.json', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/epoch_12.pth', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/latest.pth', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/tf_logs/events.out.tfevents.1662057647.konos5.fav.zcu.cz.1020547.0', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/tf_logs/events.out.tfevents.1662059590.konos5.fav.zcu.cz.1020547.1', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/tf_logs/events.out.tfevents.1662060272.konos5.fav.zcu.cz.1020547.2', '/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps/tf_logs/events.out.tfevents.1662060432.konos5.fav.zcu.cz.1020547.3']

# %%
filelist
# Out:
# [PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00001.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00002.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00003.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00004.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00005.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00006.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00007.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00008.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00009.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00010.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00011.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00012.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00013.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00014.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00015.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00016.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00017.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00018.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00019.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/orig/images_test/00020.jpg')]

# %%
list(local_output_data_dir.glob("*"))
# Out:
# [PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/demo_output.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00001.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00002.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00003.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00004.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00005.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00006.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00007.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00008.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00009.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00010.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00011.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00012.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00013.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00014.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00015.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00016.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00017.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00018.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00019.jpg'),
#  PosixPath('/scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00020.jpg')]

# %%
import skimage
import random
plt.figure(figsize=(15,10))
plt.imshow(skimage.io.imread(random.choice(list(local_output_data_dir.glob("*.jpg")))))

# %%
# %tensorboard --logdir /scratch/mjirik/job_12577867.meta-pbs.metacentrum.cz/data/processed/tutorial_exps

# %%
# !cp  -r "$SCRATCHDIR"/data/processed/ /storage/plzen4-ntis/projects/korpusy_cv/pilsen_pigs_patches_processed/$(date +"%Y-%m-%d_%H%M")

# %%
# !ls "$SCRATCHDIR"/data/processed/*
# Out:
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/demo_output.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00001.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00002.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00003.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00004.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00005.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00006.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00007.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00008.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00009.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00010.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00011.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00012.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00013.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00014.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00015.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00016.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00017.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00018.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00019.jpg
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/pred_00020.jpg
#
# /scratch/mjirik/job_12614076.meta-pbs.metacentrum.cz/data/processed/tutorial_exps:
# None.log.json  epoch_12.pth  latest.pth  tf_logs
